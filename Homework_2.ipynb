# %% [markdown]
# ### Задание №1 к уроку №4

# %% [markdown]
# Напишите код, моделирующий выпадение поля в рулетке (с учетом поля зеро).

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
from pylab import rcParams

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# Игровое поле рулетки делится на 38 ячеек: 36 зон с цифрами + 2 зоны “zero” и “double zero”.

# %%
roulette_cells, attempt = [], []
NUMBER_OF_OBSERVATIONS = 50

for i in range(1, NUMBER_OF_OBSERVATIONS + 1):
    cell = np.random.np.random.randint(0, 39)
    
    # Убираем данную часть кода, чтобы можно было визуализировать полученные данные
    #if cell==37:
    #    roulette_cells.append('zero')
    #elif cell==38:
    #    roulette_cells.append('double zero')
    #else:
    
    attempt.append(i)
    roulette_cells.append(cell)

# %%
result_info = pd.Series(roulette_cells, index=attempt)

# %%
# Построение графика выпавших значений рулетки
rcParams['figure.figsize'] = NUMBER_OF_OBSERVATIONS/5, 5
result_info.plot('bar')
plt.show()

# %% [markdown]
# ### Задание №2 к уроку №4

# %% [markdown]
# Сгенерируйте десять выборок случайных чисел х0, …, х9 и постройте гистограмму распределения случайной суммы х0 + х1 + … + х9.

# %%
# Генерация векторов
x0 = np.random.rand(1000)
x1 = np.random.rand(1000)
x2 = np.random.rand(1000)
x3 = np.random.rand(1000)
x4 = np.random.rand(1000)
x5 = np.random.rand(1000)
x6 = np.random.rand(1000)
x7 = np.random.rand(1000)
x8 = np.random.rand(1000)
x9 = np.random.rand(1000)

# Получем сумму векторов
X_vectors = x0 + x1 + x2 + x3 + x4 + x5 + x6 + x7 + x8 + x9

# %%
plt.hist(X_vectors, bins=10, edgecolor='black')
plt.show()

# %% [markdown]
# ### Задание №3 к уроку №4

# %% [markdown]
# Дополните код Монте-Карло последовательности независимых испытаний расчетом соответствующих вероятностей (через биномиальное распределение) и сравните результаты.

# %%
k, n = 0, 100
a = np.random.randint(0, 2, n)
b = np.random.randint(0, 2, n)
c = np.random.randint(0, 2, n)
d = np.random.randint(0, 2, n)
x = a + b + c + d
for i in range(0, n):
    if x[i] == 2:
        k += 1
p = k / n
q = 1 - p
print(k, n, p)

C = int(math.factorial(n)/(math.factorial(k) * math.factorial(n - k)))
print(f'C = {C}')

P = C * (p ** k) * (q ** (n - k))
print(f'P = {P}')
# Out:
# 39 100 0.39
# C = 9013924030034630826029744128
# P = 0.08157432769400094

# %% [markdown]
# Повторите расчеты, взяв другие значения n и k.

# %%
k, n = 0, 200
a = np.random.randint(0, 2, n)
b = np.random.randint(0, 2, n)
c = np.random.randint(0, 2, n)
d = np.random.randint(0, 2, n)
x = a + b + c + d
for i in range(0, n):
    if x[i] == 3:
        k += 1
p = k / n
q = 1 - p
print(k, n, p)

C = int(math.factorial(n)/(math.factorial(k) * math.factorial(n - k)))
print(f'C = {C}')

P = C * (p ** k) * (q ** (n - k))
print(f'P = {P}')
# Out:
# 48 200 0.24
# C = 48446890288948804365777873810904739734565683200
# P = 0.06592824796970542

# %% [markdown]
# ### Задание №4 к уроку №4

# %% [markdown]
# Повторите расчеты, взяв другие значения n и k.

# %%
for p in itertools.permutations('012345', 3):
    print(''.join(str(x) for x in p))
count = 6 * 5 * 4
print(f'Число размещений: {count}')
# Out:
# 012
# 013
# 014
# 015
# 021
# 023
# 024
# 025
# 031
# 032
# 034
# 035
# 041
# 042
# 043
# 045
# 051
# 052
# 053
# 054
# 102
# 103
# 104
# 105
# 120
# 123
# 124
# 125
# 130
# 132
# 134
# 135
# 140
# 142
# 143
# 145
# 150
# 152
# 153
# 154
# 201
# 203
# 204
# 205
# 210
# 213
# 214
# 215
# 230
# 231
# 234
# 235
# 240
# 241
# 243
# 245
# 250
# 251
# 253
# 254
# 301
# 302
# 304
# 305
# 310
# 312
# 314
# 315
# 320
# 321
# 324
# 325
# 340
# 341
# 342
# 345
# 350
# 351
# 352
# 354
# 401
# 402
# 403
# 405
# 410
# 412
# 413
# 415
# 420
# 421
# 423
# 425
# 430
# 431
# 432
# 435
# 450
# 451
# 452
# 453
# 501
# 502
# 503
# 504
# 510
# 512
# 513
# 514
# 520
# 521
# 523
# 524
# 530
# 531
# 532
# 534
# 540
# 541
# 542
# 543
# Число размещений: 120

# %%
for p in itertools.combinations('012345', 4):
    print(''.join(str(x) for x in p))
combination = math.factorial(6) / (math.factorial(4) * math.factorial(2))
print(f'Число сочетаний: {combination}')
# Out:
# 0123
# 0124
# 0125
# 0134
# 0135
# 0145
# 0234
# 0235
# 0245
# 0345
# 1234
# 1235
# 1245
# 1345
# 2345
# Число сочетаний: 15.0

# %% [markdown]
# ### Задание №5 к уроку №4

# %% [markdown]
# Дополните код расчетом коэффициента корреляции x и y по формуле

# %%
n = 100
r = 0.7
x = np.random.rand(n)
y = r * x + (1 - r) * np.random.rand(n)
plt.plot(x, y, 'o')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

A = np.vstack([x, np.ones(len(x))]).T
a, b = np.linalg.lstsq(A, y)[0]
plt.plot([0, 1], [b, a + b])
plt.show()

correlation_coefficient = np.corrcoef(x, y)
print(f'Коэффициент корреляции: {correlation_coefficient[0, 1]}')

xm = np.mean(x)
ym = np.mean(y)
correlation_coefficient_manual = np.sum((x - xm) * (y - ym)) / (np.sqrt(np.sum((x - xm) ** 2) * np.sum((y - ym) ** 2)))
print(f'Коэффициент корреляции, посчитанный вручную: {correlation_coefficient_manual}')
# Out:
# Коэффициент корреляции: 0.8988557826407619
# Коэффициент корреляции, посчитанный вручную: 0.8988557826407617
